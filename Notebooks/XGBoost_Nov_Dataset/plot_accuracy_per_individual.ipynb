# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Rat Model

# %%
data_dict = {'Animal_Data': ['S7068', 'S7069', 'S7070', 'S7071', 'S7072', 'S7083', 'S7088', 'S7091', 'S7092',
                         'S7094', 'S7101', 'S7076', 'S7086'],
           'Accuracy': [0.450738, 0.982799, 0.895515, 0.938765, 0.895185, 0.998352, 0.780216, 0.976515,
                         0.783074, 0.928795, 0.930187, 0.727393, 0.885462],
           'Dataset': ['Training', 'Training', 'Training', 'Training', 'Training', 'Training', 'Training', 
                      'Training', 'Training', 'Training', 'Training', 'Test', 'Test']} 

plot_data = pd.DataFrame(data = data_dict)

# %%
# Setting the style and font size
sns.set_style("white", rc={'axes.labelsize': 20, 'axes.titlesize': 20})

palette_bar = ['skyblue', 'orangered']

# Creating the plot
fig, axs = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
sns.barplot(data=plot_data, x='Animal_Data', y='Accuracy', hue='Dataset',
            errorbar=('se'), linewidth=4, ax=axs, dodge=0.9, width = 1.0,
           palette = palette_bar)  # Adjust dodge for bar closeness

# Making axes lines thicker
for axis in ['top','bottom','left','right']:
    axs.spines[axis].set_linewidth(2)  # Adjust linewidth for axes thickness

# Increase the size of the axes labels if needed
axs.set_xlabel('Animal ID', fontsize=20)  # Edit the label text and font size as needed
axs.set_ylabel('Accuracy', fontsize=20)

sns.despine()
#plt.show()

os.chdir('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/accuracy_by_animal.png', format = 'png')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/accuracy_by_animal.svg', format = 'svg')

# %% [markdown]
# ## Patient Data

# %%
human_dict = {'Patient_Data': ['P10', 'P16', 'P17', 'P20', 'P21', 'P24', 'P26', 'P27', 'P28',
                              'P5', 'P6', 'P1', 'P7'],
           'Accuracy': [1.0, 1.0, 1.0, 0.92, 0.97, 0.98, 0.99, 0.97, 0.94, 0.97, 1.0, 0.88, 0.80],
           'Dataset': ['Training', 'Training', 'Training', 'Training', 'Training', 'Training', 'Training', 
                      'Training', 'Training', 'Training', 'Training', 'Test', 'Test']} 

human_data = pd.DataFrame(data = human_dict)
human_data
# Out:
#    Patient_Data  Accuracy   Dataset
# 0           P10      1.00  Training
# 1           P16      1.00  Training
# 2           P17      1.00  Training
# 3           P20      0.92  Training
# 4           P21      0.97  Training
# 5           P24      0.98  Training
# 6           P26      0.99  Training
# 7           P27      0.97  Training
# 8           P28      0.94  Training
# 9            P5      0.97  Training
# 10           P6      1.00  Training
# 11           P1      0.88      Test
# 12           P7      0.80      Test

# %%
# Setting the style and font size
sns.set_style("white", rc={'axes.labelsize': 20, 'axes.titlesize': 20})

palette_bar = ['skyblue', 'orangered']

# Creating the plot
fig, axs = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
sns.barplot(data=human_data, x='Patient_Data', y='Accuracy', hue='Dataset',
            errorbar=('se'), linewidth=4, ax=axs, dodge=0.9, width = 1.0,
           palette = palette_bar)  # Adjust dodge for bar closeness

# Making axes lines thicker
for axis in ['top','bottom','left','right']:
    axs.spines[axis].set_linewidth(2)  # Adjust linewidth for axes thickness

# Increase the size of the axes labels if needed
axs.set_xlabel('Patient ID', fontsize=20)  # Edit the label text and font size as needed
axs.set_ylabel('Accuracy', fontsize=20)

sns.despine()
#plt.show()

os.chdir('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Human/Model_Evaluation_Plots/accuracy_by_patient.png', format = 'png')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Human/Model_Evaluation_Plots/accuracy_by_patient.svg', format = 'svg')

# %% [markdown]
# ## Logistic Regression

# %%
data_dict = {'Animal_Data': ['S7068', 'S7069', 'S7070', 'S7071', 'S7072', 'S7083', 'S7088', 'S7091', 'S7092',
                         'S7094', 'S7101', 'S7076', 'S7086'],
           'Accuracy': [0.448, 0.955, 0.72, 0.95, 0.885, 0.965, 0.818, 0.967,
                         0.637, 0.905, 0.77, 0.33, 0.75],
           'Dataset': ['Training', 'Training', 'Training', 'Training', 'Training', 'Training', 'Training', 
                      'Training', 'Training', 'Training', 'Training', 'Test', 'Test']} 

plot_data = pd.DataFrame(data = data_dict)

# %%
# Setting the style and font size
sns.set_style("white", rc={'axes.labelsize': 20, 'axes.titlesize': 20})

palette_bar = ['skyblue', 'orangered']

# Creating the plot
fig, axs = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
sns.barplot(data=plot_data, x='Animal_Data', y='Accuracy', hue='Dataset',
            errorbar=('se'), linewidth=4, ax=axs, dodge=0.9, width = 1.0,
           palette = palette_bar)  # Adjust dodge for bar closeness

# Making axes lines thicker
for axis in ['top','bottom','left','right']:
    axs.spines[axis].set_linewidth(2)  # Adjust linewidth for axes thickness

# Increase the size of the axes labels if needed
axs.set_xlabel('Animal ID', fontsize=20)  # Edit the label text and font size as needed
axs.set_ylabel('Accuracy', fontsize=20)

sns.despine()
#plt.show()

os.chdir('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/accuracy_by_animal_log_reg.png', format = 'png')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/accuracy_by_animal_log_reg.svg', format = 'svg')

# %% [markdown]
# ## Patient Data

# %%
human_dict = {'Patient_Data': ['P10', 'P16', 'P17', 'P20', 'P21', 'P24', 'P26', 'P27', 'P28',
                              'P5', 'P6', 'P1', 'P7'],
           'Accuracy': [0.99, 1.0, 1.0, 0.98, 1.0, 1.0, 0.99, 0.94, 0.99, 0.99, 1.0, 0.31, 0.97],
           'Dataset': ['Training', 'Training', 'Training', 'Training', 'Training', 'Training', 'Training', 
                      'Training', 'Training', 'Training', 'Training', 'Test', 'Test']} 

human_data = pd.DataFrame(data = human_dict)
human_data
# Out:
#    Patient_Data  Accuracy   Dataset
# 0           P10      0.99  Training
# 1           P16      1.00  Training
# 2           P17      1.00  Training
# 3           P20      0.98  Training
# 4           P21      1.00  Training
# 5           P24      1.00  Training
# 6           P26      0.99  Training
# 7           P27      0.94  Training
# 8           P28      0.99  Training
# 9            P5      0.99  Training
# 10           P6      1.00  Training
# 11           P1      0.31      Test
# 12           P7      0.97      Test

# %%
# Setting the style and font size
sns.set_style("white", rc={'axes.labelsize': 20, 'axes.titlesize': 20})

palette_bar = ['skyblue', 'orangered']

# Creating the plot
fig, axs = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
sns.barplot(data=human_data, x='Patient_Data', y='Accuracy', hue='Dataset',
            errorbar=('se'), linewidth=4, ax=axs, dodge=0.9, width = 1.0,
           palette = palette_bar)  # Adjust dodge for bar closeness

# Making axes lines thicker
for axis in ['top','bottom','left','right']:
    axs.spines[axis].set_linewidth(2)  # Adjust linewidth for axes thickness

# Increase the size of the axes labels if needed
axs.set_xlabel('Patient ID', fontsize=20)  # Edit the label text and font size as needed
axs.set_ylabel('Accuracy', fontsize=20)

sns.despine()
#plt.show()

os.chdir('/home/melissa/RESULTS/FINAL_MODEL/Rat/Evaluation_Plots/')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Human/Model_Evaluation_Plots/accuracy_by_patient_log_reg.png', format = 'png')
plt.savefig('/home/melissa/RESULTS/FINAL_MODEL/Human/Model_Evaluation_Plots/accuracy_by_patient_log_reg.svg', format = 'svg')
